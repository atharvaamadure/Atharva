# %%
#Q1]  Data Understanding and Preprocessing:

# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns
from imblearn.over_sampling import RandomOverSampler
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split , GridSearchCV
from sklearn.pipeline import make_pipeline

# %%
df=pd.read_excel("data.xlsx")
df.head()
# Out:
#       Bankrupt?  ROA(C) before interest and depreciation before interest  \
# 0             1                                           0.370594
# 1             1                                           0.464291
# 2             1                                           0.426071
# 3             1                                           0.399844
# 4             1                                           0.465022
# ...         ...                                                ...
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6816          0                                           0.472725
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#       ROA(A) before interest and % after tax  \
# 0                                   0.424389
# 1                                   0.538214
# ...

# %%
df['Bankrupt?'].value_counts(normalize= True).plot(kind= 'bar')
plt.xlabel("Bankrupt classes")
plt.ylabel("Frequancy")
plt.title("Class balance")
# Out:
# Text(0.5, 1.0, 'Class balance')

# %%
# Conclusion :- from above bar graph,0 bankrupt is is more

# %%
x51[Return On Total Assets(C)]
X52[Return On Total Assets(A)]
X53 [Return On Total Assets(B)]

# %%
import matplotlib 
from matplotlib import pyplot as plt 
import pylab
from pylab import plot,show,legend,plot,title,xlabel,ylabel

# %%
x_train=df.iloc[:6819]
x_train
# Out:
#       Bankrupt?  ROA(C) before interest and depreciation before interest  \
# 0             1                                           0.370594
# 1             1                                           0.464291
# 2             1                                           0.426071
# 3             1                                           0.399844
# 4             1                                           0.465022
# ...         ...                                                ...
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6816          0                                           0.472725
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#       ROA(A) before interest and % after tax  \
# 0                                   0.424389
# 1                                   0.538214
# ...

# %%
import statsmodels.api as sm

# %%
from statsmodels.formula.api import ols

# %%
plt.scatter('ROA(C) before interest and depreciation before interest','ROA(A) before interest and % after tax',data=df)

# %%
#From above we observe that there is no outliers

# %%
corr = df.drop(columns=['Bankrupt?']).corr()
sns.heatmap(corr);

# %%
# Conclusion:-From above graph we observe that non industry income and expenditure/revenue lies 0.75-1

# %%
target = "Bankrupt?"
X = df.drop(columns=[target])
y = df[target]

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (6819, 95)
# y shape: (6819,)

# %%
x_train=df.iloc[:6819]
x_train
# Out:
#       Bankrupt?  ROA(C) before interest and depreciation before interest  \
# 0             1                                           0.370594
# 1             1                                           0.464291
# 2             1                                           0.426071
# 3             1                                           0.399844
# 4             1                                           0.465022
# ...         ...                                                ...
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6816          0                                           0.472725
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#       ROA(A) before interest and % after tax  \
# 0                                   0.424389
# 1                                   0.538214
# ...

# %%
y_train=x_train

# %%
y_test=x_test

# %%
x_train=x_train.drop("am",axis=1)

# %%
x_test=x_test.drop("am",axis=1)

# %%
x_train=sm.add_constant(x_train,prepend=False)
x_train
# Out:
#       Bankrupt?  ROA(C) before interest and depreciation before interest  \
# 0             1                                           0.370594
# 1             1                                           0.464291
# 2             1                                           0.426071
# 3             1                                           0.399844
# 4             1                                           0.465022
# ...         ...                                                ...
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6816          0                                           0.472725
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#       ROA(A) before interest and % after tax  \
# 0                                   0.424389
# 1                                   0.538214
# ...

# %%
H0:-significant features influencing bankruptcy
H1:-insignificant features influencing bankruptcy

# %%
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import norm,binom,t,poisson

import statsmodels 
from statsmodels import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
import statsmodels.stats.multicomp
from statsmodels.stats.multicomp import pairwise_tukeyhsd
